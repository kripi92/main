# %%
import json
from json import JSONDecodeError, JSONEncoder

# %% [markdown]
# ## JSON

# %% [markdown]
# ### Loading JSON

# %%
jsonString = '{"a": "apple", "b": "bear", "c": "cat",}'
try:
    json.loads(jsonString)
except JSONDecodeError:
    print('Could not parse JSON!')
# Out:
# Could not parse JSON!

# %%
{'a': 'apple', 'b': 'bear', 'c': 'cat',}
# Out:
# {'a': 'apple', 'b': 'bear', 'c': 'cat'}

# %% [markdown]
# ### Dumping JSON

# %%
pythonDict = {'a': 'apple', 'b': 'bear', 'c': 'cat',}
json.dumps(pythonDict)
# Out:
# '{"a": "apple", "b": "bear", "c": "cat"}'

# %% [markdown]
# ### Custom JSON Decoders

# %%
class Animal:
    def __init__(self, name):
        self.name = name

class AnimalEncoder(JSONEncoder):
    def default(self, o):
        if type(o) == Animal:
            return o.name
        return super().default(o)
    
pythonDict = {'a': Animal('aardvark'), 'b': Animal('bear'), 'c': Animal('cat'),}
json.dumps(pythonDict, cls=AnimalEncoder)
# Out:
# '{"a": "aardvark", "b": "bear", "c": "cat"}'

# %%
myString = "My name is Kanza. I live in Rome and I date Vincenso"

def cleanWord(word):
    return word.replace('.', '').lower()

# Split the string into words and clean them
#cleaned_words = [cleanWord(word) for word in myString.split()]
#print(cleaned_words)

cleaned_words = [cleanWord(word) for word in myString.split() if len(cleanWord(word)) < 3]
print(cleaned_words)
# Out:
# ['my', 'is', 'i', 'in', 'i']
